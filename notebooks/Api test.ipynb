# %%
# %%time

import pickle
from api.common.utils import file_response
from engine.query import Query


ENCODING = 'utf-8'

database = 'mimic' # 'CW'
owner = 'ICSF'
query = Query(owner, database)
q1 = query.load()
# Out:
# WARNING:root:Model ready!
# CPU times: user 634 ms, sys: 131 ms, total: 765 ms
# Wall time: 814 ms

# %%
graph = q1.dependency_graph
print(graph.get_table('d_cpt'))
# Out:
# d_cpt
# 	callout
# 		row_id=submit_wardid
# 		row_id=curr_wardid
# 		row_id=callout_wardid
# 		mincodeinsubsection=callout_wardid
# 		maxcodeinsubsection=submit_wardid
# 	caregivers
# 		row_id=row_id
# 		mincodeinsubsection=row_id
# 		mincodeinsubsection=cgid
# 		maxcodeinsubsection=row_id
# 		maxcodeinsubsection=cgid
# 	chartevents_1
# 		row_id=itemid
# 		mincodeinsubsection=subject_id
# 		mincodeinsubsection=itemid
# 	chartevents_2
# 		row_id=itemid
# 		mincodeinsubsection=subject_id
# 		maxcodeinsubsection=itemid
# 	chartevents
# 		row_id=itemid
# 		mincodeinsubsection=subject_id
# 		mincodeinsubsection=itemid
# 		maxcodeinsubsection=itemid
# 	diagnoses_icd
# 		row_id=seq_num
# 		mincodeinsubsection=seq_num
# 		maxcodeinsubsection=seq_num
# 	d_items
# 		row_id=row_id
# 		row_id=itemid
# 		mincodeinsubsection=row_id
# 		mincodeinsubsection=itemid
# 		maxcodeinsubsection=row_id
# 		maxcodeinsubsection=itemid
# 	d_labitems
# 		row_id=row_id
# 		mincodeinsubsection=row_id
# 		maxcodeinsubsection=row_id
# 	procedures_icd
# 		row_id=seq_num
# 		mincodeinsubsection=seq_num
# 		maxcodeinsubsection=seq_num
# 	inputevents_mv
# 		category=cancelreason
# 	procedureevents_mv
# 		category=cancelreason
# 	admissions
# 		mincodeinsubsection=subject_id
# 	chartevents_3
# 		mincodeinsubsection=subject_id
# 		mincodeinsubsection=itemid
# 		maxcodeinsubsection=itemid
# 	chartevents_4
# 		mincodeinsubsection=subject_id
# 		mincodeinsubsection=itemid
# 	chartevents_5
# 		mincodeinsubsection=subject_id
# 		maxcodeinsubsection=itemid
# 	chartevents_6
# 		mincodeinsubsection=subject_id
# 		maxcodeinsubsection=itemid
# 	chartevents_7
# 		mincodeinsubsection=subject_id
# 		mincodeinsubsection=itemid
# 		maxcodeinsubsection=itemid
# 	chartevents_8
# 		mincodeinsubsection=subject_id
# 		maxcodeinsubsection=itemid
# 	chartevents_10
# 		mincodeinsubsection=subject_id
# 	chartevents_11
# 		mincodeinsubsection=subject_id
# 	chartevents_12
# 		mincodeinsubsection=subject_id
# 	cptevents
# 		mincodeinsubsection=subject_id
# 		mincodeinsubsection=cpt_number
# 		maxcodeinsubsection=cpt_number
# 	datetimeevents
# 		mincodeinsubsection=subject_id
# 	drgcodes
# 		mincodeinsubsection=subject_id
# 	icustays
# 		mincodeinsubsection=subject_id
# 	inputevents_cv
# 		mincodeinsubsection=subject_id
# 	labevents
# 		mincodeinsubsection=subject_id
# 	microbiologyevents
# 		mincodeinsubsection=subject_id
# 	outputevents
# 		mincodeinsubsection=subject_id
# 	patients
# 		mincodeinsubsection=subject_id
# 	prescriptions
# 		mincodeinsubsection=subject_id
# 	services
# 		mincodeinsubsection=subject_id
# 	transfers
# 		mincodeinsubsection=subject_id

# %%
print(len(graph.get_tables()))
print(len([t for t in graph.get_tables() if len(graph.get_table(t).get_joins()) > 0]), 'in the graph')
for t in graph.get_tables():
    table = graph.get_table(t)
    print((table.name+' '*30)[:30], len(table.get_joins()))
# Out:
# 39
# 39 in the graph
# admissions                     34
# d_items                        38
# callout                        38
# chartevents_1                  38
# chartevents_2                  36
# chartevents_3                  36
# chartevents_4                  36
# chartevents_5                  36
# chartevents_6                  36
# chartevents_7                  36
# chartevents_8                  35
# chartevents_10                 35
# chartevents_11                 35
# chartevents_12                 35
# chartevents_13                 34
# chartevents_14                 33
# chartevents_15                 34
# chartevents_16                 33
# chartevents_17                 33
# chartevents                    37
# cptevents                      35
# datetimeevents                 35
# drgcodes                       35
# d_cpt                          33
# icustays                       34
# inputevents_cv                 32
# inputevents_mv                 35
# labevents                      35
# microbiologyevents             34
# outputevents                   35
# patients                       34
# prescriptions                  34
# procedureevents_mv             35
# services                       35
# transfers                      34
# caregivers                     31
# diagnoses_icd                  8
# d_labitems                     15
# procedures_icd                 7

# %%
def display(results):
    first = True
    for res in results:
        score = res['score']
        name = res['column_name']
        data = res['data']
        print('Score:{}\t{}'.format(round(score, 2), name))
        print(' '.join([(el+' '*50)[:27]+'  ' for el in data[:12]]), '\n')
        print('-'*30+'\nOTHER RESULTS\n\n' if first else '', end='')
        first = False

# %%
res = query.find('CITY')
display(res)
# Out:
# Score:0.97	mimic.addresses.city
# Bram                          Auxerre                       Haute-Goulaine                Guer                          Rivesaltes                    Port-en-Bessin-Huppain        La Bridoire                   Condom                        Bourges                       La Guérinière                 La Voivre                     Espira-de-l'Agly
#
# ------------------------------
# OTHER RESULTS
#
# Score:0.38	mimic.d_icd_diagnoses.short_title
# Open brain lac-deep coma      Spirillary fever              Fail sterile endoscopy        Unc behav neo pineal          Open wound of wrist           Patellar tendinitis           Necrotizing fasciitis         Colon inj mult site-open      Triplet pregnancy-unspec      Liver lacerat unspcf cls      Lung - kaposi's sarcoma       Argentous cornea deposit
#
# Score:0.34	mimic.d_icd_procedures.short_title
# Arth/pros rem wo re-foot      Radius & ulna biopsy          Remov skel musc stimulat      Transureteroureterostomy      Extraocul mus transposit      Part adrenalectomy NEC        Cardiopulm resuscita NOS      Other control gast hem        Vaginal douche                Oth remove ovaries/tubes      Large bowel incision          Otoscopy
#
# Score:0.34	mimic.d_icd_diagnoses.long_title
# Balanoposthitis               Carcinoma in situ of esopha   Unspecified infection or in   Frostbite of hand             Leukoplakia of penis          Tuberculosis of limb bones,   Acute myocardial infarction   Chronic gastric ulcer witho   Varicose veins of legs comp   Hemophilus meningitis         Hodgkin's disease, nodular    Longitudinal deficiency of
#
# Score:0.32	mimic.d_cpt.subsectionheader
# Evocative/suppression testi   Non-face-to-face physician    Diagnostic ultrasound         Office/other outpatient ser   Neck                          Diagnostic imaging            Hydration, therapeutic, pro   Medical nutrition therapy     Radiologic guidance           Drug testing                  Complex chronic care coordi   Hospital observation servic
#
# Score:0.31	mimic.d_icd_procedures.long_title
# Destruction of lesion of ce   Augmentation rhinoplasty      Other local excision or des   Suture of laceration of che   Injection of insulin          Internal and combined versi   Aspiration of other soft ti   Microscopic examination of    Ligation of vas deferens      Closure of other fistula of   Ileal conduitogram            Suture of laceration of bla
#
# Score:0.3	mimic.d_labitems.label
# Cancer Antigen 27.29          Lymphs                        pCO2                          Iron Stain                    Total Collection Time         TdT                           Fetal Hemoglobin              Prostate Specific Antigen     Albumin                       CD33                          Lymphocytes                   Tricyclic Antidepressant Sc
#
# Score:0.28	mimic.prescriptions.drug_name_poe
#                               Bisacodyl                     Pantoprazole                  Ascorbic Acid                 Furosemide                    Pentamidine-Inhalation                                                                                                  Sodium Bicarbonate            Potassium Chloride            Methadone
#
# Score:0.28	mimic.d_items.label
# RLL Lung Sounds               mupirocin ointment            Drain Out #2 Sump             Nephramine                    j-tube flush                  Thrombocyte suspension        repogle drainage out          Press Sore Site #2            Auqafor                       tongue midline                vac                           Indwelling Port (PortaCath)
#
# Score:0.27	mimic.chartevents_17.value
# Circulation adequate          Items within reach            Right arm                     Tube feed                     Tube feed                     Continued                     Both arms                     Continued                     3 rails up                    Bed locked in low position    No                            Adequate lighting

# %%
for column_name, column in query.model.classification.items():
    print(column['labels'])
# Out:
# {'NAME': 0.03333333333333333, 'CODE': 0.9666666666666667}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.006666666666666667, 'CODE': 0.9933333333333333}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.02, 'CODE': 0.98}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.1, 'CODE': 0.9}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.013333333333333334, 'CODE': 0.9866666666666667}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0033333333333333335, 'CODE': 0.9966666666666667}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.6533333333333333, 'CODE': 0.3466666666666667}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.05, 'CODE': 0.95}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.043333333333333335, 'CODE': 0.9566666666666667}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.15333333333333332, 'CODE': 0.8466666666666667}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0033333333333333335, 'CODE': 0.9966666666666667}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.01, 'CODE': 0.99}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.016666666666666666, 'CODE': 0.9833333333333333}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
# {'NAME': 0.0, 'CODE': 1.0}
